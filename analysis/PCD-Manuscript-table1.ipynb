# %%
import pandas as pd
import geopandas as gpd

# %%
df = pd.read_parquet('pcd_usgs_9_sites_laz.parquet')

# %%
df
# Out:
#                      workunit               description quality_level  \
# 0        WY_FEMA_East_B9_2019    glaciers / mountainous          QL 2
# 1         CO_WestCentral_2019  coniferous / mountainous          QL 2
# 2  TX_DesertMountains_B1_2018     shrubland / grassland          QL 2
# 3          CA_YosemiteNP_2019  coniferous / mountainous          QL 1
# 4           GA_Central_3_2019                mixed lulc          QL 2
# 5             WI_Brown_2_2020          urban / wetlands          QL 1
# 6  NE_Northeast_Phase2_2_2020                  cropland          QL 2
# 7            AZ_PimaCo_2_2021             desert / mine          QL 1
# 8       CA_SanFrancisco_1_B23                     urban          QL 0
#
#    dem_gsd_m                                               urls  urls_count  \
# 0       1.00  [https://rockyweb.usgs.gov/vdelivery/Datasets/...         773
# 1       1.00  [https://rockyweb.usgs.gov/vdelivery/Datasets/...         238
# ...

# %%
ls *20250709_*
# Out:
# 20250709_PCD_3dep_als_footprints.geojson
# 20250709_PCD_3dep_als_footprints.parquet
# 20250709_PCD_3dep_fourway_overlap.geojson
# 20250709_PCD_3dep_gedi_tracks.geojson
# 20250709_PCD_3dep_is2_tracks.geojson
# 20250709_PCD_3dep_stereo_footprints.geojson

# %%
als_footprints_data = gpd.read_file('20250709_PCD_3dep_als_footprints.geojson')
gedi_track_data = gpd.read_file('20250709_PCD_3dep_gedi_tracks.geojson')
is2_data = gpd.read_file('20250709_PCD_3dep_is2_tracks.geojson')
stereo_data = gpd.read_file('20250709_PCD_3dep_stereo_footprints.geojson')

# %%
als_footprints_data
# Out:
#                 usgs_workunit               description start_datetime  \
# 0        WY_FEMA_East_B9_2019    glaciers / mountainous     2019-07-26
# 1         CO_WestCentral_2019  coniferous / mountainous     2019-08-21
# 2  TX_DesertMountains_B1_2018     shrubland / grassland     2019-09-11
# 3          CA_YosemiteNP_2019  coniferous / mountainous     2019-10-07
# 4           GA_Central_3_2019                mixed lulc     2020-02-02
# 5             WI_Brown_2_2020          urban / wetlands     2020-05-07
# 6  NE_Northeast_Phase2_2_2020                  cropland     2020-11-16
# 7            AZ_PimaCo_2_2021             desert / mine     2021-09-27
# 8       CA_SanFrancisco_1_B23                     urban     2023-04-20
#
#   end_datetime    ql                                             sensor  \
# 0   2019-09-22  QL 2      Leica Terrain Mapper and Optech Galaxy PRIME
# 1   2019-09-19  QL 2                                      Riegl VQ1560i
# ...

# %%
gedi_track_data
# Out:
#             usgs_workunit                                    gedi_granule_id  \
# 0    WY_FEMA_East_B9_2019  GEDI02_A_2019194055411_O03298_02_T00155_02_003...
# 1    WY_FEMA_East_B9_2019  GEDI02_A_2019200084834_O03393_03_T03035_02_003...
# 2    WY_FEMA_East_B9_2019  GEDI02_A_2019209000122_O03527_02_T04730_02_003...
# 3    WY_FEMA_East_B9_2019  GEDI02_A_2019211043557_O03561_03_T00847_02_003...
# 4    WY_FEMA_East_B9_2019  GEDI02_A_2019219194832_O03695_02_T03965_02_003...
# ..                    ...                                                ...
# 61       AZ_PimaCo_2_2021  GEDI02_A_2021261011319_O15667_02_T08065_02_003...
# 62       AZ_PimaCo_2_2021  GEDI02_A_2021264234230_O15728_02_T10605_02_003...
# 63       AZ_PimaCo_2_2021  GEDI02_A_2021285225842_O16053_03_T08636_02_003...
# 64       AZ_PimaCo_2_2021  GEDI02_A_2021332204942_O16780_02_T08218_02_003...
# 65  CA_SanFrancisco_1_B23  GEDI02_A_2023028212552_O23387_02_T09397_02_003...
#
# ...

# %%
stereo_data
# Out:
#                  usgs_workunit                id  \
# 0         WY_FEMA_East_B9_2019  1020010086976A00
# 1         WY_FEMA_East_B9_2019  1020010089403600
# 2          CO_WestCentral_2019  102001008BD60800
# 3          CO_WestCentral_2019  1020010088168700
# 4   TX_DesertMountains_B1_2018  1030010097D5CC00
# 5   TX_DesertMountains_B1_2018  10300100984A3A00
# 6           CA_YosemiteNP_2019  102001008E543300
# 7           CA_YosemiteNP_2019  102001008EE06B00
# 8            GA_Central_3_2019  10300100A26FD700
# 9            GA_Central_3_2019  10300100A132F900
# 10             WI_Brown_2_2020  104001005ACC6E00
# 11             WI_Brown_2_2020  104001005B461800
# 12  NE_Northeast_Phase2_2_2020  10200100A1228A00
# 13  NE_Northeast_Phase2_2_2020  102001009D48BC00
# 14  NE_Northeast_Phase2_2_2020  10200100A0BEE600
# 15  NE_Northeast_Phase2_2_2020  10200100A0A9E600
# 16            AZ_PimaCo_2_2021  104001006D788E00
# 17            AZ_PimaCo_2_2021  104001006E942500
# ...

# %%
ls *neon*als*geojson
# Out:
# 20250718_PCD_neon_als_footprints.geojson

# %%
neon_als_footprints_data = gpd.read_file('20250718_PCD_neon_als_footprints.geojson')

# %%
neon_als_footprints_data
# Out:
#   neon_id            description            start_datetime  \
# 0    BART  mixed hardwood forest 2019-08-25 14:05:12+00:00
# 1    REDB  deciduous conifer mix 2021-05-20 07:00:00+00:00
# 2    WREF         conifer forest 2019-07-12 08:00:00+00:00
#
#                end_datetime          sensor wavelength_nm  \
# 0 2019-08-25 19:20:01+00:00     ALTM Gemini          1064
# 1 2021-05-21 06:59:59+00:00  RIEGL LMS-Q780          1064
# 2 2019-07-15 07:59:59+00:00  RIEGL LMS-Q780          1064
#
#   avg_point_density_m2 ground_return_point_density_m2  \
# 0                  5.9                            2.3
# 1                   17                              7
# 2                   18                              3
#
#   horizontal_uncertainty_avg_m vertical_uncertainty_avg_m  \
# 0                          0.5                       0.13
# 1                         0.19                      0.088
# 2                         0.19                        0.1
#
# ...

# %%
ncalm_sfm_footprint = gpd.read_file('20250722_PCD_ncalm_sfm_footprints.geojson')

# %%
ncalm_sfm_footprint
# Out:
#                ncalm_id description start_datetime end_datetime  \
# 0  OTLAS.092021.32611.1       fault     2020-02-15   2020-02-18
#
#                   sensor wavelength_nm avg_point_density_m2  \
# 0  S.O.D.A. Camera (SfM)          None               192.36
#
#   ground_return_point_density_m2 horizontal_uncertainty_avg_m  \
# 0                           None                        0.019
#
#   vertical_uncertainty_avg_m  \
# 0                      0.033
#
#                                             geometry
# 0  POLYGON ((-115.73157 33.35367, -115.73451 33.3...

# %%
stereo_neon_data = gpd.read_file('20250718_PCD_neon_stereo_footprints.geojson')

# %%
stereo_neon_data
# Out:
#   neon_id                id   datetime collection  geolocation_uncertainty  \
# 0    BART  10300100988FA400 2019-09-22       wv02                 5.413742
# 1    BART  1030010098464200 2019-09-22       wv02                 5.995574
# 2    BART  1030010093B2F600 2019-06-10       wv02                 5.779450
# 3    BART  1030010092D6AF00 2019-06-10       wv02                 7.990128
# 4    REDB  10200100B1301200 2021-06-04       wv01                 6.996440
# 5    REDB  10200100B1172E00 2021-06-04       wv01                 6.445797
# 6    REDB  10200100B1551C00 2021-05-22       wv01                 6.029474
# 7    REDB  10200100B1630600 2021-05-22       wv01                 7.117176
# 8    WREF  10300100965CBA00 2019-07-24       wv02                 5.693468
# 9    WREF  10300100962F3500 2019-07-24       wv02                 6.257399
#
#         gsd  target_to_spacecraft_elevation_avg  view:azimuth  view:off_nadir  \
# ...

# %%
stereo_ncalm_data = gpd.read_file('20250722_PCD_ncalm_stereo_footprints.geojson')

# %%
stereo_ncalm_data
# Out:
#                ncalm_id                id   datetime collection  \
# 0  OTLAS.092021.32611.1  10300100A178D600 2020-01-31       wv02
# 1  OTLAS.092021.32611.1  10300100A3456700 2020-01-31       wv02
#
#    geolocation_uncertainty       gsd  target_to_spacecraft_elevation_avg  \
# 0                 2.121252  0.464631                           86.706828
# 1                 2.641926  0.583624                           58.081182
#
#    view:azimuth  view:off_nadir  view:sun_azimuth  view:sun_elevation  \
# 0    118.784715        3.009589        156.413705           35.909457
# 1    188.818980       28.298882        156.144341           35.789016
#
#                                             geometry
# 0  POLYGON ((-115.78093 33.94113, -115.78087 33.9...
# 1  POLYGON ((-115.79298 33.9843, -115.79312 33.96...
